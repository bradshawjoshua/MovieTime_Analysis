# %% [markdown]
# ## Project 3

# %%
# Base Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
# data
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
ratings.replace({'\\N':np.nan}, inplace=True)

# %% [markdown]
# ## Basics Preprocessing

# %%
basics
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9156665  tt9916754      movie  Chico Albuquerque - Revelações
# 9156671  tt9916766  tvEpisode                  Episode #10.15
# 9156706  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9156713  tt9916856      short                        The Wind
# 9156714  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult startYear endYear  \
# 0                            Carmencita       0      1894     NaN
# 1                Le clown et ses chiens       0      1892     NaN
# 2                        Pauvre Pierrot       0      1892     NaN
# 3                           Un bon bock       0      1892     NaN
# 4                      Blacksmith Scene       0      1893     NaN
# ...                                 ...     ...       ...     ...
# 9156665  Chico Albuquerque - Revelações       0      2013     NaN
# 9156671                  Episode #10.15       0      2019     NaN
# 9156706      Horrid Henry's Comic Caper       0      2014     NaN
# 9156713                        The Wind       0      2015     NaN
# 9156714       Horrid Henry Knows It All       0      2014     NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9156665             49                  Documentary
# 9156671             43  Family,Game-Show,Reality-TV
# 9156706             11   Adventure,Animation,Comedy
# 9156713             27                        Short
# 9156714             10   Adventure,Animation,Comedy
#
# [2394117 rows x 9 columns]

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2394117 entries, 0 to 9156714
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 182.7+ MB

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.9       256
# 2  tt0000003            6.5      1702
# 3  tt0000004            5.7       168
# 4  tt0000005            6.2      2517

# %% [markdown]
# Title Basics:
# * Replace "\N" with np.nan --
# * Eliminate movies that are null for runtimeMinutes
# * Eliminate movies that are null for genre
# * keep only titleType==Movie---
# * keep startYear 2000-2022
# * Eliminate movies that include "Documentary" in genre (see tip below

# %%
basics.replace({'\\N':np.nan}, inplace=True)

# %%
basics = basics.dropna(axis=0, how='any', thresh=None, subset=['runtimeMinutes', 'genres'], inplace=False)

# %%
basics_filtered = basics[(basics.titleType == "movie") & ((basics['startYear'] >= "2000") & (basics['startYear'] <= "2022"))]

# %%
basics_filtered
# Out:
#             tconst titleType  \
# 13079    tt0013274     movie
# 34790    tt0035423     movie
# 61089    tt0062336     movie
# 66304    tt0067683     movie
# 67635    tt0069049     movie
# ...            ...       ...
# 9156480  tt9916362     movie
# 9156564  tt9916538     movie
# 9156605  tt9916622     movie
# 9156632  tt9916680     movie
# 9156665  tt9916754     movie
#
#                                               primaryTitle  \
# 13079                          Istoriya grazhdanskoy voyny
# 34790                                       Kate & Leopold
# 61089    The Tango of the Widower and Its Distorting Mi...
# 66304             Workers '71: Nothing About Us Without Us
# 67635                           The Other Side of the Wind
# ...                                                    ...
# 9156480                                              Coven
# 9156564                                Kuambil Lagi Hatiku
# 9156605        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9156632  De la ilusión al desconcierto: cine colombiano...
# 9156665                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 13079                          Istoriya grazhdanskoy voyny       0      2021
# 34790                                       Kate & Leopold       0      2001
# 61089            El Tango del Viudo y Su Espejo Deformante       0      2020
# 66304                   Robotnicy 1971 - Nic o nas bez nas       0      2006
# 67635                           The Other Side of the Wind       0      2018
# ...                                                    ...     ...       ...
# 9156480                                           Akelarre       0      2020
# 9156564                                Kuambil Lagi Hatiku       0      2019
# 9156605        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9156632  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9156665                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                  genres
# 13079       NaN            133             Documentary
# 34790       NaN            118  Comedy,Fantasy,Romance
# 61089       NaN             70                   Drama
# 66304       NaN             47             Documentary
# 67635       NaN            122                   Drama
# ...         ...            ...                     ...
# 9156480     NaN             92           Drama,History
# 9156564     NaN            123                   Drama
# 9156605     NaN             57             Documentary
# 9156632     NaN            100             Documentary
# 9156665     NaN             49             Documentary
#
# [214802 rows x 9 columns]

# %%
is_documentary = basics_filtered['genres'].str.contains('documentary',case=False)
basics_cleaned = basics_filtered[~is_documentary]

# %%
basics_cleaned
# Out:
#             tconst titleType  \
# 34790    tt0035423     movie
# 61089    tt0062336     movie
# 67635    tt0069049     movie
# 77929    tt0079644     movie
# 86766    tt0088751     movie
# ...            ...       ...
# 9156387  tt9916170     movie
# 9156396  tt9916190     movie
# 9156435  tt9916270     movie
# 9156480  tt9916362     movie
# 9156564  tt9916538     movie
#
#                                               primaryTitle  \
# 34790                                       Kate & Leopold
# 61089    The Tango of the Widower and Its Distorting Mi...
# 67635                           The Other Side of the Wind
# 77929                                        November 1828
# 86766                                    The Naked Monster
# ...                                                    ...
# 9156387                                      The Rehearsal
# 9156396                                          Safeguard
# 9156435                           Il talento del calabrone
# 9156480                                              Coven
# 9156564                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear endYear  \
# 34790                               Kate & Leopold       0      2001     NaN
# 61089    El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67635                   The Other Side of the Wind       0      2018     NaN
# 77929                                November 1828       0      2001     NaN
# 86766                            The Naked Monster       0      2005     NaN
# ...                                            ...     ...       ...     ...
# 9156387                                   O Ensaio       0      2019     NaN
# 9156396                                  Safeguard       0      2020     NaN
# 9156435                   Il talento del calabrone       0      2020     NaN
# 9156480                                   Akelarre       0      2020     NaN
# 9156564                        Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                     genres
# 34790              118     Comedy,Fantasy,Romance
# 61089               70                      Drama
# 67635              122                      Drama
# 77929              140                  Drama,War
# 86766              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9156387             51                      Drama
# 9156396             95  Action,Adventure,Thriller
# 9156435             84                   Thriller
# 9156480             92              Drama,History
# 9156564            123                      Drama
#
# [142175 rows x 9 columns]

# %% [markdown]
# ## AKAs Preprocessing

# %%
akas.replace({'\\N':np.nan}, inplace=True)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0
