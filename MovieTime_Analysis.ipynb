# %% [markdown]
# ## Project 3

# %%
# Base Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
# data
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)

# %%
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)

# %%
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)

# %% [markdown]
# ## Basics Preprocessing

# %%
basics
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9156665  tt9916754      movie  Chico Albuquerque - Revelações
# 9156671  tt9916766  tvEpisode                  Episode #10.15
# 9156706  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9156713  tt9916856      short                        The Wind
# 9156714  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult startYear endYear  \
# 0                            Carmencita       0      1894     NaN
# 1                Le clown et ses chiens       0      1892     NaN
# 2                        Pauvre Pierrot       0      1892     NaN
# 3                           Un bon bock       0      1892     NaN
# 4                      Blacksmith Scene       0      1893     NaN
# ...                                 ...     ...       ...     ...
# 9156665  Chico Albuquerque - Revelações       0      2013     NaN
# 9156671                  Episode #10.15       0      2019     NaN
# 9156706      Horrid Henry's Comic Caper       0      2014     NaN
# 9156713                        The Wind       0      2015     NaN
# 9156714       Horrid Henry Knows It All       0      2014     NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9156665             49                  Documentary
# 9156671             43  Family,Game-Show,Reality-TV
# 9156706             11   Adventure,Animation,Comedy
# 9156713             27                        Short
# 9156714             10   Adventure,Animation,Comedy
#
# [2394117 rows x 9 columns]

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2394117 entries, 0 to 9156714
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 182.7+ MB

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.9       256
# 2  tt0000003            6.5      1702
# 3  tt0000004            5.7       168
# 4  tt0000005            6.2      2517

# %% [markdown]
# Title Basics:
# * Replace "\N" with np.nan --
# * Eliminate movies that are null for runtimeMinutes
# * Eliminate movies that are null for genre
# * keep only titleType==Movie---
# * keep startYear 2000-2022
# * Eliminate movies that include "Documentary" in genre (see tip below

# %%
basics.replace({'\\N':np.nan}, inplace=True)

# %%
basics = basics.dropna(axis=0, how='any', thresh=None, subset=['runtimeMinutes', 'genres'], inplace=False)

# %%
basics_filtered = basics[(basics.titleType == "movie") & ((basics['startYear'] >= "2000") & (basics['startYear'] <= "2022"))]

# %%
basics_filtered.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 13079  tt0013274     movie                        Istoriya grazhdanskoy voyny
# 34790  tt0035423     movie                                     Kate & Leopold
# 61089  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 66304  tt0067683     movie           Workers '71: Nothing About Us Without Us
# 67635  tt0069049     movie                         The Other Side of the Wind
#
#                                    originalTitle isAdult startYear endYear  \
# 13079                Istoriya grazhdanskoy voyny       0      2021     NaN
# 34790                             Kate & Leopold       0      2001     NaN
# 61089  El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 66304         Robotnicy 1971 - Nic o nas bez nas       0      2006     NaN
# 67635                 The Other Side of the Wind       0      2018     NaN
#
#       runtimeMinutes                  genres
# 13079            133             Documentary
# 34790            118  Comedy,Fantasy,Romance
# 61089             70                   Drama
# 66304             47             Documentary
# 67635            122                   Drama

# %%
is_documentary = basics_filtered['genres'].str.contains('documentary',case=False)
basics_cleaned = basics_filtered[~is_documentary]

# %%
basics_cleaned.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34790  tt0035423     movie                                     Kate & Leopold
# 61089  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67635  tt0069049     movie                         The Other Side of the Wind
# 77929  tt0079644     movie                                      November 1828
# 86766  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult startYear endYear  \
# 34790                             Kate & Leopold       0      2001     NaN
# 61089  El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67635                 The Other Side of the Wind       0      2018     NaN
# 77929                              November 1828       0      2001     NaN
# 86766                          The Naked Monster       0      2005     NaN
#
#       runtimeMinutes                  genres
# 34790            118  Comedy,Fantasy,Romance
# 61089             70                   Drama
# 67635            122                   Drama
# 77929            140               Drama,War
# 86766            100    Comedy,Horror,Sci-Fi

# %% [markdown]
# ## AKAs Preprocessing

# %%
akas.replace({'\\N':np.nan}, inplace=True)

# %%
akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 32874312  tt9916852         5             Episódio #3.20     PT       pt
# 32874313  tt9916852         6             Episodio #3.20     IT       it
# 32874314  tt9916852         7               एपिसोड #3.20     IN       hi
# 32874315  tt9916856         1                   The Wind     DE      NaN
# 32874316  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay            NaN               0
# 1                 NaN  literal title               0
# 2         imdbDisplay            NaN               0
# 3         imdbDisplay            NaN               0
# 4         imdbDisplay            NaN               0
# ...               ...            ...             ...
# 32874312          NaN            NaN               0
# 32874313          NaN            NaN               0
# 32874314          NaN            NaN               0
# 32874315  imdbDisplay            NaN               0
# 32874316     original            NaN               1
#
# [32874317 rows x 8 columns]

# %%
akas_us = akas['region'] == 'US'

# %%
akas_cleaned = akas.loc[akas_us]

# %%
akas_cleaned
# Out:
#             titleId  ordering                          title region language  \
# 5         tt0000001         6                     Carmencita     US      NaN
# 14        tt0000002         7         The Clown and His Dogs     US      NaN
# 33        tt0000005        10               Blacksmith Scene     US      NaN
# 36        tt0000005         1            Blacksmithing Scene     US      NaN
# 41        tt0000005         6            Blacksmith Scene #1     US      NaN
# ...             ...       ...                            ...    ...      ...
# 32873989  tt9916702         1  Loving London: The Playground     US      NaN
# 32874026  tt9916720        10                The Demonic Nun     US      NaN
# 32874028  tt9916720        12                      The Nun 2     US      NaN
# 32874045  tt9916756         1       Pretty Pretty Black Girl     US      NaN
# 32874061  tt9916764         1                             38     US      NaN
#
#                 types             attributes isOriginalTitle
# 5         imdbDisplay                    NaN               0
# 14                NaN  literal English title               0
# 33        imdbDisplay                    NaN               0
# 36        alternative                    NaN               0
# 41        alternative                    NaN               0
# ...               ...                    ...             ...
# 32873989          NaN                    NaN               0
# 32874026           tv                    NaN               0
# 32874028  imdbDisplay                    NaN               0
# 32874045  imdbDisplay                    NaN               0
# 32874061  imdbDisplay                    NaN               0
#
# [1342956 rows x 8 columns]

# %% [markdown]
# ## Ratings Preprocessing

# %%
ratings.replace({'\\N':np.nan}, inplace=True)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.9       256
# 2  tt0000003            6.5      1702
# 3  tt0000004            5.7       168
# 4  tt0000005            6.2      2517

# %% [markdown]
# ## Filtering Basics on AKAs

# %%
keepers =basics_cleaned['tconst'].isin(akas_cleaned['titleId'])
keepers
# Out:
# 34790       True
# 61089       True
# 67635       True
# 77929      False
# 86766       True
#            ...
# 9156387     True
# 9156396     True
# 9156435    False
# 9156480     True
# 9156564    False
# Name: tconst, Length: 142175, dtype: bool

# %%
basics_cleaned = basics_cleaned[keepers]
basics_cleaned.head()
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9940\778872479.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   basics_cleaned = basics_cleaned[keepers]
#           tconst titleType                                       primaryTitle  \
# 34790  tt0035423     movie                                     Kate & Leopold
# 61089  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67635  tt0069049     movie                         The Other Side of the Wind
# 86766  tt0088751     movie                                  The Naked Monster
# 92731  tt0094859     movie                                         Chief Zabu
#
#                                    originalTitle isAdult startYear endYear  \
# 34790                             Kate & Leopold       0      2001     NaN
# 61089  El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67635                 The Other Side of the Wind       0      2018     NaN
# 86766                          The Naked Monster       0      2005     NaN
# 92731                                 Chief Zabu       0      2016     NaN
#
#       runtimeMinutes                  genres
# 34790            118  Comedy,Fantasy,Romance
# 61089             70                   Drama
# 67635            122                   Drama
# 86766            100    Comedy,Horror,Sci-Fi
# 92731             74                  Comedy

# %%
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz']

# %%
basics_cleaned.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
akas_cleaned.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
